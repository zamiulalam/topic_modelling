# %%
from bertopic import BERTopic
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %%
path = '/Users/zamiulalam/Documents/Andrew Project/Topic Modelling/WSJ + NYT dataset.xlsx'

df = pd.read_excel(path)

# %%
docs = df['Text'].tolist()

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

topic_model = BERTopic(
    embedding_model=embedding_model,
    vectorizer_model=CountVectorizer(stop_words="english"),
    min_topic_size=10
    )

topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                      Name  \
# 0      -1    277                -1_said_tesla_musk_company
# 1       0    177               0_chatgpt_ai_openai_chatbot
# 2       1     61        1_students_school_schools_teachers
# 3       2     56                   2_tesla_musk_gm_company
# 4       3     55            3_bank_market_stocks_investors
# 5       4     45                4_mangione_police_asher_mr
# 6       5     35                  5_google_search_apple_ai
# 7       6     31                      6_musk_mr_trump_doge
# 8       7     30                    7_trump_mr_cohen_party
# 9       8     30           8_vehicles_safety_tesla_driving
# 10      9     28                9_ai_cloud_billion_startup
# 11     10     28               10_oil_energy_china_climate
# 12     11     26          11_said_california_vegas_angeles
# 13     12     24                   12_byd_chinese_china_ev
# 14     13     24                   13_hua_chinese_china_xu
# 15     14     22                        14_et_wsj_com_says
# 16     15     21   15_multiplan_insurers_patients_medicare
# 17     16     21                    16_musk_tesla_mr_board
# 18     17     21                    17_musk_sec_twitter_mr
# 19     18     20                    18_jobs_ai_job_college
# 20     19     18         19_openai_copyright_times_lawsuit
# 21     20     17          20_bil_tax_democrats_republicans
# 22     21     15             21_ukraine_russia_putin_trump
# 23     22     15  22_political_election_campaign_elections
# 24     23     15            23_autopilot_tesla_crash_mcgee
# 25     24     14                 24_israel_gaza_iran_hamas
# 26     25     13                  25_altman_openai_musk_mr
# 27     26     13            26_patients_doctors_dr_medical
# 28     27     13            27_disney_ai_characters_studio
# 29     28     13          28_law_richard_university_school
# 30     29     12                        29_et_wsj_says_com
#
#                                        Representation  \
# 0   [said, tesla, musk, company, mr, trump, year, ...
# 1   [chatgpt, ai, openai, chatbot, chatbots, like,...
# 2   [students, school, schools, teachers, student,...
# 3   [tesla, musk, gm, company, said, electric, car...
# 4   [bank, market, stocks, investors, year, inflat...
# 5   [mangione, police, asher, mr, said, credit, fa...
# 6   [google, search, apple, ai, company, said, ant...
# 7   [musk, mr, trump, doge, government, spacex, fe...
# 8   [trump, mr, cohen, party, democratic, class, d...
# 9   [vehicles, safety, tesla, driving, cars, recal...
# 10  [ai, cloud, billion, startup, said, companies,...
# 11  [oil, energy, china, climate, states, united, ...
# 12  [said, california, vegas, angeles, las, los, o...
# 13  [byd, chinese, china, ev, tariffs, cars, vehic...
# 14  [hua, chinese, china, xu, exam, government, de...
# 15  [et, wsj, com, says, analysts, growth, shares,...
# 16  [multiplan, insurers, patients, medicare, heal...
# 17  [musk, tesla, mr, board, company, private, sha...
# 18  [musk, sec, twitter, mr, brazil, starlink, sai...
# 19  [jobs, ai, job, college, workers, students, wo...
# 20  [openai, copyright, times, lawsuit, companies,...
# 21  [bil, tax, democrats, republicans, trump, shut...
# 22  [ukraine, russia, putin, trump, war, president...
# 23  [political, election, campaign, elections, spe...
# 24  [autopilot, tesla, crash, mcgee, car, driver, ...
# 25  [israel, gaza, iran, hamas, israeli, trump, ne...
# 26  [altman, openai, musk, mr, board, company, mic...
# 27  [patients, doctors, dr, medical, health, docto...
# 28  [disney, ai, characters, studio, nov, mulaney,...
# 29  [law, richard, university, school, warren, llm...
# 30  [et, wsj, says, com, analysts, note, auto, ana...
#
#                                   Representative_Docs
# 0   [Tech That Will Change Your Life in 2024; Gene...
# 1   [What Is ChatGPT? What to Know About the AI Ch...
# 2   [Don’t Ban ChatGPT in Schools. Teach With It.;...
# 3   [Battery Storage Growth Boosts Tesla Profits\n...
# 4   [What a Slowing Jobs Market Might Mean for Int...
# 5   [Suspect in Insurance C.E.O. Killing Creates W...
# 6   [Google's Antitrust Loss Set to Reshape Search...
# 7   [Musk the Contractor vs. Musk the U.S. Adviser...
# 8   [Trump Pushes for Radical Changes Across the P...
# 9   [Tesla to Recall 362,000 Cars With Its ‘Full S...
# 10  [The 27-Year-Old Billionaire Whose Army Does A...
# 11  [Saudi Arabia’s ‘Whatever It Takes’ Strategy B...
# 12  [Investigators Search for Links Between New Or...
# 13  [China's E.V. Innovations Worry Rivals Elsewhe...
# 14  [China Puts Power of State Behind AI—and Risks...
# 15  [Tech, Media &Telecom Roundup: Market Talk Pro...
# 16  [Tool Helps Insurers Shift Costs To Patients\n...
# 17  [Investors Take Musk to Trial Over Plan for Te...
# 18  [Elon Musk Can't Stall SEC Investigation, Judg...
# 19  [Foot in Door? Not With A.I. Doing the Job.\n\...
# 20  [OpenAI Seeks to Dismiss Parts of The New York...
# 21  [The Post-Shutdown Deluge; A lot of government...
# 22  [Vladimir Putin Messed Up\n\nWe explain Presid...
# 23  [New Era of AI Deepfakes Complicates 2024 Elec...
# 24  [Tesla Driver Testifies Autopilot Failed to Pr...
# 25  [Friday Briefing: Hamas Targets Tel Aviv\n\nPl...
# 26  [OpenAI Breached Contract, Musk Says\n\nMusk s...
# 27  [A.I.'s Helping Hand\n\nOn Nov. 30 last year, ...
# 28  [Uncanny Art for the Post-Truth Era; Arts and ...
# 29  [Paid Notice: Deaths LUBMAN, STANLEY B\n\nLUBM...
# 30  [Auto &Transport Roundup: Market Talk\n\nThe l...

# %%
topic_model.visualize_heatmap()

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_barchart()
